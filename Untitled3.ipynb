# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snsy
from sklearn.linear_model import LinearRegression
from scipy import stats
from matplotlib.font_manager import FontProperties

# %%
file = r"Covid_custom.xls"

CVdata_county = pd.read_excel(file, sheet_name="Sheet1") #by county
CVdata_RD = pd.read_excel(file, sheet_name="Sheet2") #race #doses
CVdata_whogetsit = pd.read_excel(file, sheet_name="Sheet3") #demographics of elderly and healthcare workers and educators
#CVdata = pd.concat([CVdata_county ,CVdata_AGR ,CVdata_AD ,CVdata_CA ,CVdata_CR ])

# %%
CVdata_whogetsit
# Out:
#     County Name  Total Doses Allocated  Vaccine Doses Administered  \
# 0      Anderson                   9800                        6377
# 1       Andrews                   3300                        6726
# 2      Angelina                  28300                       19878
# 3       Aransas                   2300                        6504
# 4        Archer                   1600                        2742
# ..          ...                    ...                         ...
# 249        Wood                   4500                        9702
# 250      Yoakum                   1700                        1975
# 251       Young                   5200                        4250
# 252      Zapata                   3000                        4118
# 253      Zavala                    600                        4752
#
#      People Vaccinated with at least One Dose  People Fully Vaccinated  \
# 0                                        4050                     2428
# ...

# %%
CVdata_county.head()
# Out:
#     County  2010_CensusPopulation
# 0   Dallas                2368139
# 1   Harris                4092459
# 2  Tarrant                1809034
# 3    Bexar                1714773
# 4   Travis                1024266

# %%
CVdata_RD.head()
# Out:
#      County Race/Ethnicity  Doses Administered  People Fully Vaccinated
# 0  Anderson          Asian                  45                       16
# 1  Anderson          Black                 484                      147
# 2  Anderson       Hispanic                 215                       74
# 3  Anderson          White                4333                     1747
# 4  Anderson          Other                 389                      139

# %%
CVdata_county["2010_CensusPopulation"].mean()
# Out:
# 98998.27165354331

# %%
new_list= []

for i in CVdata_county["2010_CensusPopulation"]>= 98998:
    new_list.append(i)

# %%
x= CVdata_county.loc[CVdata_county["2010_CensusPopulation"]>=98998]

# %%
z1= CVdata_RD.loc[CVdata_RD["County"]=="Dallas"]
z2= CVdata_RD.loc[CVdata_RD["County"]=="Harris"]
z3= CVdata_RD.loc[CVdata_RD["County"]=="Tarrant"]
z4= CVdata_RD.loc[CVdata_RD["County"]=="Bexar"]
z5= CVdata_RD.loc[CVdata_RD["County"]=="Travis"]
z6= CVdata_RD.loc[CVdata_RD["County"]=="Collin"]
z7= CVdata_RD.loc[CVdata_RD["County"]=="El Paso"]
z8= CVdata_RD.loc[CVdata_RD["County"]=="Galveston"]
z9= CVdata_RD.loc[CVdata_RD["County"]=="Denton"]
z10= CVdata_RD.loc[CVdata_RD["County"]=="Fort Bend"]
z11= CVdata_RD.loc[CVdata_RD["County"]=="Hidalgo"]
z12= CVdata_RD.loc[CVdata_RD["County"]=="Cameron"]

# %%
fig, ax= plt.subplots( figsize=(10,8))
ax.bar(z12["Race/Ethnicity"], z12["Doses Administered"], label="Doses Allocated Cameron", alpha=0.5, edgecolor="k")
ax.bar(z11["Race/Ethnicity"], z11["Doses Administered"], label="Doses Allocated Hidalgo", alpha=0.5, edgecolor="k")
plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Doses Administered ")
plt.title("Total Doses Allocated Overlaid with Doses Administered by County")
# Out:
# Text(0.5, 1.0, 'Total Doses Allocated Overlaid with Doses Administered by County')

# %%
fig, ax= plt.subplots( figsize=(10,8))
ax.bar(z11["Race/Ethnicity"], z11["Doses Administered"], label="Doses Allocated Cameron", alpha=0.5, edgecolor="k")
plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Doses Administered ")
plt.title("Total Doses Allocated Overlaid with Doses Administered by County")
# Out:
# Text(0.5, 1.0, 'Total Doses Allocated Overlaid with Doses Administered by County')

# %%
fig, ax= plt.subplots( figsize=(18,10))
ax.bar(z12["Race/Ethnicity"], z12["Doses Administered"], label="Doses Allocated Cameron", fill= False, edgecolor="r")
ax.bar(z11["Race/Ethnicity"], z11["Doses Administered"], label="Doses Allocated Hidalgo", fill= False, edgecolor="orange")
ax.bar(z10["Race/Ethnicity"], z10["Doses Administered"], label="Doses Allocated Fort Bend", fill= False, edgecolor='yellow')
ax.bar(z9["Race/Ethnicity"], z9["Doses Administered"], label="Doses Allocated Denton", fill= False, edgecolor='green')
ax.bar(z8["Race/Ethnicity"], z8["Doses Administered"], label="Doses Allocated Galveston", fill= False, edgecolor='blue')
ax.bar(z7["Race/Ethnicity"], z7["Doses Administered"], label="Doses Allocated El Paso", fill= False, edgecolor='purple')
ax.bar(z6["Race/Ethnicity"], z6["Doses Administered"], label="Doses Allocated Collin", fill= False, edgecolor='sienna')
ax.bar(z5["Race/Ethnicity"], z5["Doses Administered"], label="Doses Allocated Travis", fill= False, edgecolor='magenta')
ax.bar(z4["Race/Ethnicity"], z4["Doses Administered"], label="Doses Allocated Bexas", fill= False, edgecolor='cyan')
ax.bar(z3["Race/Ethnicity"], z3["Doses Administered"], label="Doses Allocated Tarrent", fill= False, edgecolor='lime')
ax.bar(z2["Race/Ethnicity"], z2["Doses Administered"], label="Doses Allocated Harris", fill= False, edgecolor='olive')
ax.bar(z1["Race/Ethnicity"], z1["Doses Administered"], label="Doses Allocated Dallas", fill= False, edgecolor='k')

#ax.bar(z12["County"],z12["Doses Administered"], label="Doses Administered Cameron", alpha=0.5)
#ax.bar(z11["County"],z11["Doses Administered"], label="Doses Administered Hidalgo", alpha=0.5)
#ax.bar(z10["County"],z10["Doses Administered"], label="Doses Administered Fort Bend", alpha=0.5)
#ax.bar(z9["County"], z9["Doses Administered"], label="Doses Administered Denton", alpha=0.5)
#ax.bar(z8["County"], z8["Doses Administered"], label="Doses Administered Galveston", alpha=0.5)
#ax.bar(z7["County"], z7["Doses Administered"], label="Doses Administered El Paso", alpha=0.5)
#ax.bar(z6["County"], z6["Doses Administered"], label="Doses Administered Collin", alpha=0.5)
#ax.bar(z5["County"], z5["Doses Administered"], label="Doses Administered Travis", alpha=0.5)
#ax.bar(z4["County"], z4["Doses Administered"], label="Doses Administered Bexas", alpha=0.5)
#ax.bar(z3["County"], z3["Doses Administered"], label="Doses Administered Tarrent", alpha=0.5)
#ax.bar(z2["County"], z2["Doses Administered"], label="Doses Administered Harris", alpha=0.5)
#ax.bar(z1["County"], z1["Doses Administered"], label="Doses Administered Dallas", alpha=0.5)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Doses Administered ")
plt.title("Total Doses Allocated Overlaid with Doses Administered by County")
# Out:
# Text(0.5, 1.0, 'Total Doses Allocated Overlaid with Doses Administered by County')

# %%
y1= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Dallas"]
y2= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Harris"]
y3= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Tarrant"]
y4= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Bexar"]
y5= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Travis"]
y6= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Collin"]
y7= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="El Paso"]
y8= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Galveston"]
y9= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Denton"]
y10= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Fort Bend"]
y11= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Hidalgo"]
y12= CVdata_whogetsit[.loc[CVdata_whogetsit["County Name"]=="Cameron"]

# %%
y12
# Out:
#    County Name  Total Doses Allocated  Vaccine Doses Administered  \
# 30     Cameron                 143015                      127363
#
#     People Vaccinated with at least One Dose  People Fully Vaccinated  \
# 30                                     81887                    46415
#
#     Population, 16+  Population, 65+  Population, Phase 1A Healthcare Workers  \
# 30           311689            58607                                    29737
#
#     Population, Phase 1A Long-term Care Residents  \
# 30                                           6315
#
#     Population, 16-64\n Any Medical Condition  \
# 30                                     127806
#
#     Population, Education and Child Care Personnel
# 30                                           17059

# %%
fig, ax= plt.subplots( figsize=(10,8))
ax.bar(y12["County Name"], y12["Total Doses Allocated"], label="Doses Allocated Cameron", alpha=0.5)
ax.bar(y11["County Name"], y11["Total Doses Allocated"], label="Doses Allocated Hidalgo", alpha=0.5)
ax.bar(y10["County Name"], y10["Total Doses Allocated"], label="Doses Allocated Fort Bend", alpha=0.5)
ax.bar(y9["County Name"], y9["Total Doses Allocated"], label="Doses Allocated Denton", alpha=0.5)
ax.bar(y8["County Name"], y8["Total Doses Allocated"], label="Doses Allocated Galveston", alpha=0.5)
ax.bar(y7["County Name"], y7["Total Doses Allocated"], label="Doses Allocated El Paso", alpha=0.5)
ax.bar(y6["County Name"], y6["Total Doses Allocated"], label="Doses Allocated Collin", alpha=0.5)
ax.bar(y5["County Name"], y5["Total Doses Allocated"], label="Doses Allocated Travis", alpha=0.5)
ax.bar(y4["County Name"], y4["Total Doses Allocated"], label="Doses Allocated Bexas", alpha=0.5)
ax.bar(y3["County Name"], y3["Total Doses Allocated"], label="Doses Allocated Tarrent", alpha=0.5)
ax.bar(y2["County Name"], y2["Total Doses Allocated"], label="Doses Allocated Harris", alpha=0.5)
ax.bar(y1["County Name"], y1["Total Doses Allocated"], label="Doses Allocated Dallas", alpha=0.5)

ax.bar(y12["County Name"], y12["Vaccine Doses Administered"],label="Doses Administered Cameron", alpha=0.5)
ax.bar(y11["County Name"], y11["Vaccine Doses Administered"],label="Doses Administered Hidalgo", alpha=0.5)
ax.bar(y10["County Name"], y10["Vaccine Doses Administered"],label="Doses Administered Fort Bend", alpha=0.5)
ax.bar(y9["County Name"], y9["Vaccine Doses Administered"],label="Doses Administered Denton", alpha=0.5)
ax.bar(y8["County Name"], y8["Vaccine Doses Administered"],label="Doses Administered Galveston", alpha=0.5)
ax.bar(y7["County Name"], y7["Vaccine Doses Administered"],label="Doses Administered El Paso", alpha=0.5)
ax.bar(y6["County Name"], y6["Vaccine Doses Administered"],label="Doses Administered Collin", alpha=0.5)
ax.bar(y5["County Name"], y5["Vaccine Doses Administered"],label="Doses Administered Travis", alpha=0.5)
ax.bar(y4["County Name"], y4["Vaccine Doses Administered"],label="Doses Administered Bexas", alpha=0.5)
ax.bar(y3["County Name"], y3["Vaccine Doses Administered"],label="Doses Administered Tarrent", alpha=0.5)
ax.bar(y2["County Name"], y2["Vaccine Doses Administered"],label="Doses Administered Harris", alpha=0.5)
ax.bar(y1["County Name"], y1["Vaccine Doses Administered"],label="Doses Administered Dallas", alpha=0.5)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Total Doses Allocated ")
plt.title("Total Doses Allocated Overlaid with Doses Administered by County")
# Out:
# Text(0.5, 1.0, 'Total Doses Allocated Overlaid with Doses Administered by County')

# %%
fig, ax= plt.subplots()
ax.bar(y12["County Name"], y12["Total Doses Allocated"])
ax.bar(y11["County Name"], y11["Total Doses Allocated"])
ax.bar(y10["County Name"], y10["Total Doses Allocated"])
ax.bar(y9["County Name"], y9["Total Doses Allocated"])
ax.bar(y8["County Name"], y8["Total Doses Allocated"])
ax.bar(y7["County Name"], y7["Total Doses Allocated"])
ax.bar(y6["County Name"], y6["Total Doses Allocated"])
ax.bar(y5["County Name"], y5["Total Doses Allocated"])
ax.bar(y4["County Name"], y4["Total Doses Allocated"])
ax.bar(y3["County Name"], y3["Total Doses Allocated"])
ax.bar(y2["County Name"], y2["Total Doses Allocated"])
ax.bar(y1["County Name"], y1["Total Doses Allocated"])

plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Total Doses Allocated")
plt.title("Vaccines Administered by County")
# Out:
# Text(0.5, 1.0, 'Vaccines Allocated by County')

# %%
fig, ax= plt.subplots()
ax.bar(y12["County Name"], y12["Vaccine Doses Administered"])
ax.bar(y11["County Name"], y11["Vaccine Doses Administered"])
ax.bar(y10["County Name"], y10["Vaccine Doses Administered"])
ax.bar(y9["County Name"], y9["Vaccine Doses Administered"])
ax.bar(y8["County Name"], y8["Vaccine Doses Administered"])
ax.bar(y7["County Name"], y7["Vaccine Doses Administered"])
ax.bar(y6["County Name"], y6["Vaccine Doses Administered"])
ax.bar(y5["County Name"], y5["Vaccine Doses Administered"])
ax.bar(y4["County Name"], y4["Vaccine Doses Administered"])
ax.bar(y3["County Name"], y3["Vaccine Doses Administered"])
ax.bar(y2["County Name"], y2["Vaccine Doses Administered"])
ax.bar(y1["County Name"], y1["Vaccine Doses Administered"])

plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Vaccines Administered")
plt.title("Vaccines Administered by County")
# Out:
# Text(0.5, 1.0, 'Vaccines Administered by County')

# %%
x= pd.DataFrame(x)

# %%
xplot= x.iloc[:12]

# %%
xplot
# Out:
#        County  2010_CensusPopulation
# 0      Dallas                2368139
# 1      Harris                4092459
# 2     Tarrant                1809034
# 3       Bexar                1714773
# 4      Travis                1024266
# 5      Collin                 782341
# 6     El Paso                 800647
# 7   Galveston                 291309
# 8      Denton                 662614
# 9   Fort Bend                 585375
# 11    Hidalgo                 774769
# 12    Cameron                 406220

# %%
fig, ax= plt.subplots(figsize=(70,10))
ax.bar(CVdata_whogetsit["County Name"], CVdata_whogetsit["Vaccine Doses Administered"])
plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Vaccines Administered")
plt.title("Vaccines Administered by County")
# Out:
# Text(0.5, 1.0, 'Vaccines Administered by County')

# %%
fig, ax= plt.subplots(figsize=(70,10))
ax.bar(CVdata_whogetsit["County Name"], CVdata_whogetsit["Vaccine Doses Administered"])
plt.xticks(rotation=90)
plt.xlabel("County")
plt.ylabel("Vaccines Administered")
plt.title("Vaccines Administered by County")
# Out:
# Text(0.5, 1.0, 'Vaccines Administered by County')

# %%
f, ax = plt.subplots(figsize=(10, 10))
ax = sns.heatmap(CVdata_whogetsit.corr(), annot=True)

# %%
CVdata_whogetsit.keys()
# Out:
# Index(['County Name', 'Total Doses Allocated', 'Vaccine Doses Administered',
#        'People Vaccinated with at least One Dose', 'People Fully Vaccinated',
#        'Population, 16+', 'Population, 65+',
#        'Population, Phase 1A Healthcare Workers',
#        'Population, Phase 1A Long-term Care Residents',
#        'Population, 16-64\n Any Medical Condition',
#        'Population, Education and Child Care Personnel'],
#       dtype='object')

# %%
fig, ax= plt.subplots()
ax.bar(CVdata_RD["Race/Ethnicity"], CVdata_RD["Doses Administered"])
plt.xlabel("Race")
plt.ylabel("Doses Administered")
plt.title("Doses Administered by Race")
# Out:
# Text(0.5, 1.0, 'Doses Administered by Race')

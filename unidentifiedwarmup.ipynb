# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
a = np.arange (5, 1001, 57)
plt.plot (a, "black", marker= ".")
plt.xlabel("index")
plt.ylabel("value")
# Out:
# Text(0, 0.5, 'value')

# %%
a= np.arange(5,10,1)
plt.plot(a,"red", marker= "+")
plt.xlabel("celery consumed celery per second")
plt.ylabel("time taken to consume in seconds")
# Out:
# Text(0, 0.5, 'time taken to consume in seconds')

# %%
a = np.arange(5, 1001, 57)
plt.plot(a, 'black', marker='.')
plt.xlabel('index')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')
